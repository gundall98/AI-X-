# %% [markdown]
# <a href="https://colab.research.google.com/github/gundall98/AI-X-/blob/master/%EB%84%B7%EB%A7%88%EB%B8%94_%26_%EB%84%A5%EC%8A%A8GT_%EC%A3%BC%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt

from matplotlib import font_manager,rc
rc('font',family = 'Malgun Gothic')
from datetime import datetime

start = datetime(2017,5,12)
end = datetime(2018,5,12)

df2 = pdr.DataReader('041140.KQ', 'yahoo',start,end)
df = pdr.DataReader("251270.KS", 'yahoo',start,end)


plt.plot(df["Close"],label = "Close")

plt.legend(loc='upper left')
plt.suptitle("NetMarble",fontsize=20)
plt.title("2017056617 Park Gun")
# Out:
# Text(0.5, 1.0, '2017056617 Park Gun')

# %%
plt.plot(df2["Close"],label = "Close")

plt.legend(loc='upper left')
plt.suptitle("Nexon GT",fontsize=20)
plt.title("2017056617 Park Gun")
# Out:
# Text(0.5, 1.0, '2017056617 Park Gun')
